# %% [markdown]
# ## Imports

# %%
from ultralytics import YOLO
import torch

# %% [markdown]
# ## Verify GPU

# %%
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 3050 Laptop GPU

# %% [markdown]
# ## Load Model

# %%
model = YOLO("yolov8n.pt")

# %% [markdown]
# ## Preliminary Training

# %%
results = model.train(
    data=r"D:\Noctivium\Dev\Projects\Active\village-rooftop-detection\data.yaml",
    epochs=15,
    imgsz=640,
    batch=8,
    device=0,
    workers=2,
    project="runs/rooftop",
    name="clean_run",
    patience=10
)

# %% [markdown]
# ## Model Improvement

# %% [markdown]
# ### 50 epochs

# %%
model = YOLO("runs/rooftop/clean_run2/weights/best.pt")

# %% [markdown]
# #### Testing Model

# %%
model.predict("dataset/images/test", save=True, conf=0.25)

# %%
model.predict(
    "dataset/images/train/badetumnar_tile_020025.jpg",
    conf=0.01,
    save=True
)

# %% [markdown]
# ### Training on Higher Epochs

# %%
model = YOLO("runs/rooftop/clean_run2/weights/last.pt")

model.train(
    data=r"D:\Noctivium\Dev\Projects\Active\village-rooftop-detection\data.yaml",
    epochs=50,
    device=0,
    cos_lr=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.26 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.0  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %% [markdown]
# ### 100 epochs

# %%
model = YOLO(r"runs\detect\train2\weights\best.pt")

# %%
model.train(
    data=r"D:\Noctivium\Dev\Projects\Active\village-rooftop-detection\data.yaml",
    epochs=100,
    device=0,
    batch=4,
    workers=2,
    cos_lr=True
)
# Out:
# Ultralytics YOLOv8.2.0  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
model.predict(source=r"dataset\images\test\badetumnar_tile_048205.jpg", conf=0.1)
# Out:
# image 1/1 d:\Noctivium\Dev\Projects\Active\village-rooftop-detection\dataset\images\test\badetumnar_tile_048205.jpg: 640x640 2 RCCs, 72.8ms
# Speed: 11.5ms preprocess, 72.8ms inference, 26.6ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'RCC', 1: 'Tiled', 2: 'Tin', 3: 'Others'}
#  obb: None
#  orig_img: array([[[206, 188, 151],
#          [206, 188, 151],
#          [207, 187, 152],
#          ...,
#          [101,  98,  70],
#          [100,  97,  69],
#          [ 98,  95,  67]],
#
#         [[207, 189, 152],
#          [207, 189, 152],
#          [208, 188, 153],
#          ...,
#          [ 99,  96,  68],
#          [ 98,  95,  67],
#          [ 96,  93,  65]],
#
#         [[208, 189, 154],
#          [208, 189, 154],
#          [207, 188, 153],
#          ...,
#          [ 97,  94,  66],
#          [ 97,  94,  66],
# ...

# %% [markdown]
# ## Shift to YOLOv8m now

# %%
model = YOLO("yolov8m.pt")
# Out:
# d:\Noctivium\Dev\Projects\Active\village-rooftop-detection\.venv310\lib\site-packages\ultralytics\nn\tasks.py:732: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
model = YOLO("runs/detect/train3/weights/best.pt")

model.train(
    data=r"D:\Noctivium\Dev\Projects\Active\village-rooftop-detection\data.yaml",
    epochs=30,
    imgsz=640,
    batch=4,        # 🔥 VERY IMPORTANT
    workers=0,      # 🔥 Windows fix
    device=0,
    amp=False,      # 🔥 DISABLE AMP (important!)
    cache=False
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.26 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.0  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# Load your trained model
model = YOLO("runs/detect/train7/weights/best.pt")

# Run prediction
results = model(r"D:\Noctivium\Dev\Projects\Active\village-rooftop-detection\dataset\images\test\badetumnar_tile_019356.jpg")

# Plot result with boxes
img_with_boxes = results[0].plot()

plt.imshow(img_with_boxes)
plt.axis("off")
# Out:
# d:\Noctivium\Dev\Projects\Active\village-rooftop-detection\.venv310\lib\site-packages\ultralytics\nn\tasks.py:732: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
